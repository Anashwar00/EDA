# %% [markdown]
# # Titanic Exploratory Data Analysis (EDA) Project: Unveiling the Stories of Survival and Loss.
#
# Embark on a compelling journey through the Titanic dataset, where numbers tell the poignant tales of survival, loss, and the human dynamics aboard the iconic ship. Our EDA project delves into the depths of the Titanic dataset, dissecting demographics, ages, genders, and more to bring forth a comprehensive narrative of the passengers' fate.
#
# Objective:
# The core objective of this Titanic EDA project is to unravel the intricacies of the tragic event. By scrutinizing the dataset, we aim to shed light on the demographics of the passengers, understand the factors influencing survival, and create a vivid portrayal of the human experience aboard the ill-fated Titanic.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\jessy pinkman\Downloads\archive (38)\Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.set_option('display.max.rows',891)

# %%
df.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# 5        5            6         0       3
# 6        6            7         0       1
# 7        7            8         0       3
# 8        8            9         1       3
# 9        9           10         1       2
# 10      10           11         1       3
# 11      11           12         1       1
# 12      12           13         0       3
# 13      13           14         0       3
# 14      14           15         0       3
# 15      15           16         1       2
# 16      16           17         0       3
# 17      17           18         1       2
# 18      18           19         0       3
# 19      19           20         1       3
# 20      20           21         0       2
# ...

# %%
df.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
sns.countplot(x=df['Survived'])
df['Survived'].value_counts()


# x= x is mandatory
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sns.countplot(x=df['Pclass'],hue=df['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sns.histplot(x=df['Age'],bins=5,kde=True,hue=df['Sex'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
g = sns.FacetGrid(df, col="Sex")

# Map a histogram to the FacetGrid for the 'Age' column
g.map(sns.histplot, 'Age', bins=5, kde=True)

# Show the plot
plt.show()
# Out:
# C:\Users\jessy pinkman\.conda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(x=df['Age'],kde=True)
# Out:
# C:\Users\jessy pinkman\AppData\Local\Temp\ipykernel_8516\4242396452.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['Age'],kde=True)
# <Axes: ylabel='Density'>

# %%
# for multi->scatterplot(numeric-numeric)
# lineplot(numeric-numeric) one year-time
# bar plot numeric-category)
# box plot numeric-category)
# heatmap(category-category)
# pairplot (numeric-numeric)
# distplot (numeric -category)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sns.heatmap(pd.crosstab(df['Survived'], df['Pclass']))
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\jessy pinkman\AppData\Local\Temp\ipykernel_8516\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>
